# %%
# %load_ext autoreload
# %autoreload 2

# %%
# pl.__version__

# %%
import os
import json
import logging
import random
from pathlib import Path

import cv2 as cv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm, trange

import torch
import torch.nn as nn
import torch.optim as optim

import pytorch_lightning as pl
from pytorch_lightning import loggers as pl_loggers

# %%
import transformers
transformers.__version__
# Out:
# '3.5.0'

# %%
from iqradre.extract.data import utils 
from iqradre.extract.data import loader
from iqradre.extract.data.dataset import IDCardDataset
from iqradre.extract.config import label as label_cfg
from iqradre.extract.trainer.task import TaskLayoutLM


from transformers import BertTokenizer, AutoModel
from transformers import (
    WEIGHTS_NAME,
    AdamW,
    BertConfig,
    BertTokenizer,
    BertForTokenClassification,
    LayoutLMConfig,
    LayoutLMForTokenClassification,
    get_linear_schedule_with_warmup,
)

from seqeval.metrics import (
    classification_report,
    f1_score,
    precision_score,
    recall_score,
    accuracy_score,
)

# %%
SAVED_CHECKPOINT_PATH = "../checkpoints/v2/"
SAVED_LOGS_PATH = "../logs/v2/"

SUMMARY = "top"
MANUAL_SEED = 1261
MAX_EPOCH = 10
MAX_STEPS = None
VALCHECK_INTERVAL = 2000
NUM_GPUS = 1
DISTRIBUTED_BACKEND = None
LOG_FREQ = 100
DETERMINISTIC = True
BENCHMARK = True
CHECKPOINT_PATH = None
BATCH_SIZE = 4
NUM_WORKERS=16

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
device = "cpu"

# %%
tokenizer = BertTokenizer.from_pretrained(
    "indobenchmark/indobert-base-p2",
    do_lower_case=True,
    cache_dir=None,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-20c83b865ec4> in <module>
#       2     "indobenchmark/indobert-base-p2",
#       3     do_lower_case=True,
# ----> 4     cache_dir=None,
#       5 )
#
# /opt/anaconda3/envs/dlearn/lib/python3.6/site-packages/transformers/tokenization_utils_base.py in from_pretrained(cls, pretrained_model_name_or_path, *init_inputs, **kwargs)
#    1627                         proxies=proxies,
#    1628                         resume_download=resume_download,
# -> 1629                         local_files_only=local_files_only,
#    1630                     )
#    1631                 except requests.exceptions.HTTPError as err:
#
# /opt/anaconda3/envs/dlearn/lib/python3.6/site-packages/transformers/file_utils.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, local_files_only)
#     953             resume_download=resume_download,
#     954             user_agent=user_agent,
# --> 955             local_files_only=local_files_only,
#     956         )
#     957     elif os.path.exists(url_or_filename):
#
# /opt/anaconda3/envs/dlearn/lib/python3.6/site-packages/transformers/file_utils.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, local_files_only)
#    1123                 else:
#    1124                     raise ValueError(
# -> 1125                         "Connection error, and we cannot find the requested files in the cached path."
#    1126                         " Please try again or make sure your Internet connection is on."
#    1127                     )
#
# ValueError: Connection error, and we cannot find the requested files in the cached path. Please try again or make sure your Internet connection is on.

# %%
path = '/data/idcard/results/combined/layoutlm/20kv1'
train_loader, valid_loader = loader.get_loader(
    path, tokenizer=tokenizer, 
    batch_size=BATCH_SIZE, 
    num_workers=NUM_WORKERS,
    rand_seq=True,
    rand_seq_prob=0.5
)

# %%
len(valid_loader.dataset),(len(train_loader.dataset))
# Out:
# (13522, 54088)

# %%
res = valid_loader.dataset
# res[4]
input_ids, input_masks, segment_ids, label_ids, boxes, img, mask = res[2000]

# %%
img.shape
# Out:
# (750, 1000, 3)

# %%
config = LayoutLMConfig.from_pretrained(
    "microsoft/layoutlm-base-uncased",
    num_labels=label_cfg.num_labels,
    cache_dir=None
)

model = LayoutLMForTokenClassification.from_pretrained(
    'microsoft/layoutlm-base-uncased',
    config=config,
#     return_dict=True
)

model.resize_token_embeddings(len(tokenizer))
model = model.to(device)

# %%
class DownstreamModel(nn.Module):
    def __init__(self, layoutlm_model):
        self.layoutlm_model = layoutlm_model
        self.layoutlm_embedding = nn.Embedding(250,512)
        self.image_embedding = nn.Embedding(250,512)
        self.classifier = nn.Linear()
        
    def forward(
        self,
        input_ids=None,
        bbox=None,
        attention_mask=None,
        token_type_ids=None,
        position_ids=None,
        head_mask=None,
        inputs_embeds=None,
        labels=None,
        images=None,
        output_attentions=None,
        output_hidden_states=None,
        return_dict=None,
    ):
        
        layoutlm_outputs = self.layoutlm_model(x)
        if len(outputs)>2:
            loss, logits = layoutlm_outputs
        else:
            logits = layoutlm_outputs
        
        lylm_embed = self.layoutlm_embedding(logits)
        img_embed = self.image_embedding(logits)
        combine = torch.cat([lylm_embed, img_embed])
        
        outputs = self.classifier(combine)
        return outputs

# %%
from torchvision.models.resnet import resnet34
resnet = resnet34(pretrained=True)
resnet.fc
# Out:
# Linear(in_features=512, out_features=1000, bias=True)

# %%
embed = nn.Embedding(15,2)
input = torch.LongTensor([
    [1,12]
])

input.shape
embed(input)
# Out:
# tensor([[[-1.4523,  1.7728],
#          [-0.7685,  1.5386]]], grad_fn=<EmbeddingBackward>)

# %%
batch = next(iter(train_loader))
inputs = {
            "input_ids": batch[0].to(device),
            "attention_mask": batch[1].to(device),
            "token_type_ids": batch[2].to(device),
            "labels": batch[3].to(device),
            "bbox": batch[4].to(device)
        }
outputs = model.forward(**inputs)
loss, logits = outputs[0], outputs[1]

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-109-bed0ed29a227> in <module>
# ----> 1 embed(logits)
#
# /opt/anaconda3/envs/dlearn/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /opt/anaconda3/envs/dlearn/lib/python3.6/site-packages/torch/nn/modules/sparse.py in forward(self, input)
#     124         return F.embedding(
#     125             input, self.weight, self.padding_idx, self.max_norm,
# --> 126             self.norm_type, self.scale_grad_by_freq, self.sparse)
#     127
#     128     def extra_repr(self) -> str:
#
# /opt/anaconda3/envs/dlearn/lib/python3.6/site-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    1850         # remove once script supports set_grad_enabled
#    1851         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 1852     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    1853
#    1854
#
# RuntimeError: Expected tensor for argument #1 'indices' to have scalar type Long; but got torch.FloatTensor instead (while checking arguments for embedding)

# %%
preds = torch.argmax(logits, dim=2)
preds.shape
embed = nn.Embedding(250, 512)
embed(preds)
# Out:
# tensor([[[ 0.7477, -1.7225,  0.9895,  ..., -1.0284, -0.1249, -0.7358],
#          [ 0.1325, -1.2952,  1.7751,  ..., -0.1205,  0.1244, -0.5969],
#          [ 0.1325, -1.2952,  1.7751,  ..., -0.1205,  0.1244, -0.5969],
#          ...,
#          [ 0.1289,  0.5206, -0.5304,  ...,  0.1863, -1.2301,  0.5379],
#          [ 0.1289,  0.5206, -0.5304,  ...,  0.1863, -1.2301,  0.5379],
#          [ 0.1289,  0.5206, -0.5304,  ...,  0.1863, -1.2301,  0.5379]],
#
#         [[ 1.2384,  1.0449,  0.6403,  ..., -1.6067,  0.3973,  0.5023],
#          [ 0.1650,  0.0522, -0.5625,  ..., -0.1893, -0.9771,  1.2926],
#          [ 0.1325, -1.2952,  1.7751,  ..., -0.1205,  0.1244, -0.5969],
#          ...,
#          [ 0.1289,  0.5206, -0.5304,  ...,  0.1863, -1.2301,  0.5379],
#          [ 0.1289,  0.5206, -0.5304,  ...,  0.1863, -1.2301,  0.5379],
#          [ 0.0341, -0.6797,  1.5708,  ..., -0.8141,  0.7259,  0.2665]],
#
#         [[ 0.7477, -1.7225,  0.9895,  ..., -1.0284, -0.1249, -0.7358],
#          [ 0.1325, -1.2952,  1.7751,  ..., -0.1205,  0.1244, -0.5969],
#          [ 0.1325, -1.2952,  1.7751,  ..., -0.1205,  0.1244, -0.5969],
#          ...,
#          [ 0.1289,  0.5206, -0.5304,  ...,  0.1863, -1.2301,  0.5379],
#          [ 0.1289,  0.5206, -0.5304,  ...,  0.1863, -1.2301,  0.5379],
#          [ 0.0341, -0.6797,  1.5708,  ..., -0.8141,  0.7259,  0.2665]],
#
#         [[ 0.7477, -1.7225,  0.9895,  ..., -1.0284, -0.1249, -0.7358],
#          [ 0.1325, -1.2952,  1.7751,  ..., -0.1205,  0.1244, -0.5969],
#          [ 0.1325, -1.2952,  1.7751,  ..., -0.1205,  0.1244, -0.5969],
#          ...,
#          [ 0.1289,  0.5206, -0.5304,  ...,  0.1863, -1.2301,  0.5379],
#          [ 0.1289,  0.5206, -0.5304,  ...,  0.1863, -1.2301,  0.5379],
#          [ 0.0341, -0.6797,  1.5708,  ..., -0.8141,  0.7259,  0.2665]]],
#        grad_fn=<EmbeddingBackward>)

# %%
bsize = preds.shape[0]
labels = []
for idx in range(bsize):
    label_pred = []
    for pds in preds[idx].tolist():
        lbl = label_cfg.idx_to_label.get(pds, "O")
        label_pred.append(lbl)
    labels.append(label_pred)
# Out:
# [['L-VAL_RLG',
#   'I-FLD_WRG',
#   'U-VAL_WRG',
#   'U-VAL_GDR',
#   'O',
#   'L-VAL_NIK',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'B-FLD_KCM',
#   'U-VAL_GDR',
#   'U-VAL_ADR',
#   'U-VAL_GDR',
#   'O',
#   'U-VAL_ADR',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'U-VAL_WRG',
#   'U-VAL_GDR',
#   'I-FLD_WRG',
#   'U-VAL_WRG',
#   'U-VAL_GDR',
#   'I-FLD_WRG',
#   'L-FLD_KAB',
#   'U-VAL_ADR',
#   'I-FLD_WRG',
#   'B-VAL_SGP',
#   'U-VAL_RLG',
#   'I-VAL_KLH',
#   'U-VAL_WRG',
#   'U-VAL_GDR',
#   'U-VAL_GDR',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'B-VAL_SGP',
#   'L-FLD_KAB',
#   'O',
#   'B-VAL_SGP',
#   'U-VAL_WRG',
#   'U-VAL_GDR',
#   'U-VAL_GDR',
#   'B-VAL_KAB',
#   'O',
#   'U-VAL_WRG',
#   'B-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_WRG',
#   'I-FLD_WRG',
#   'I-VAL_SGD',
#   'U-VAL_WRG',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'U-VAL_KCM',
#   'L-FLD_KAB',
#   'I-FLD_WRG',
#   'U-VAL_RLG',
#   'L-FLD_KAB',
#   'I-FLD_WRG',
#   'I-FLD_PROV',
#   'U-VAL_WRG',
#   'L-FLD_KAB',
#   'U-VAL_KCM',
#   'I-FLD_WRG',
#   'L-FLD_KAB',
#   'I-FLD_WRG',
#   'B-VAL_SGP',
#   'U-VAL_RLG',
#   'U-VAL_WRG',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_WRG',
#   'U-VAL_WRG',
#   'L-VAL_SGP',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_WRG',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_ADR',
#   'U-VAL_WRG',
#   'I-FLD_PROV',
#   'L-FLD_KAB',
#   'U-VAL_WRG',
#   'O',
#   'L-VAL_KAB',
#   'U-VAL_KCM',
#   'U-VAL_WRG',
#   'U-VAL_WRG',
#   'I-VAL_SGD',
#   'U-VAL_RLG',
#   'U-VAL_WRG',
#   'L-FLD_KAB',
#   'U-VAL_RLG',
#   'U-VAL_GDR',
#   'I-FLD_WRG',
#   'L-FLD_KAB',
#   'I-FLD_WRG',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_GLD',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'I-VAL_SGD',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-VAL_SGD',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'I-VAL_SGD',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KCM',
#   'L-VAL_KAB',
#   'I-VAL_SGD',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-VAL_RLG',
#   'L-VAL_KAB'],
#  ['L-VAL_RLG',
#   'I-FLD_WRG',
#   'U-VAL_RLG',
#   'U-VAL_GDR',
#   'I-FLD_WRG',
#   'U-VAL_GDR',
#   'U-VAL_RLG',
#   'L-VAL_KAB',
#   'B-VAL_SGP',
#   'I-VAL_SGD',
#   'U-VAL_ADR',
#   'U-VAL_ADR',
#   'B-VAL_KRJ',
#   'U-VAL_RLG',
#   'I-FLD_WRG',
#   'U-VAL_RLG',
#   'U-VAL_RLG',
#   'U-VAL_ADR',
#   'L-VAL_KAB',
#   'I-VAL_SGD',
#   'I-FLD_WRG',
#   'U-VAL_GDR',
#   'I-FLD_WRG',
#   'U-VAL_KRJ',
#   'L-FLD_KAB',
#   'I-FLD_WRG',
#   'B-VAL_SGP',
#   'U-VAL_RLG',
#   'L-VAL_KAB',
#   'U-VAL_WRG',
#   'L-FLD_PROV',
#   'B-FLD_KAB',
#   'U-VAL_ADR',
#   'U-VAL_ADR',
#   'U-VAL_RLG',
#   'U-VAL_RLG',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_ADR',
#   'U-VAL_RLG',
#   'B-VAL_SGP',
#   'U-VAL_RLG',
#   'U-VAL_GDR',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-FLD_KAB',
#   'O',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'U-VAL_RLG',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_WRG',
#   'L-FLD_KAB',
#   'B-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_WRG',
#   'I-VAL_SGD',
#   'I-FLD_WRG',
#   'L-FLD_KAB',
#   'I-FLD_WRG',
#   'L-FLD_KAB',
#   'B-VAL_SGP',
#   'U-VAL_RLG',
#   'U-VAL_RLG',
#   'L-FLD_KAB',
#   'O',
#   'L-FLD_KAB',
#   'I-FLD_WRG',
#   'B-VAL_SGP',
#   'L-FLD_KAB',
#   'U-VAL_WRG',
#   'U-VAL_NAMA',
#   'O',
#   'U-VAL_RLG',
#   'L-FLD_PROV',
#   'B-FLD_KAB',
#   'U-VAL_ADR',
#   'L-FLD_KAB',
#   'U-VAL_RLG',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'O',
#   'I-VAL_SGD',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'I-VAL_SGD',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'I-FLD_GDR',
#   'U-VAL_RLG',
#   'I-FLD_PROV',
#   'I-VAL_SGD',
#   'O',
#   'U-VAL_WRG',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'B-VAL_TTL',
#   'L-VAL_KAB',
#   'U-VAL_ADR',
#   'I-FLD_WRG',
#   'I-FLD_WRG',
#   'U-VAL_ADR',
#   'U-VAL_ADR',
#   'U-VAL_RLG',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-VAL_SGD',
#   'L-VAL_KAB',
#   'I-VAL_SGD',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-VAL_SGD',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-VAL_SGD',
#   'L-VAL_KAB'],
#  ['U-VAL_RLG',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_KCM',
#   'B-VAL_TTL',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'I-VAL_SGD',
#   'I-VAL_SGD',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'U-VAL_GDR',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'L-VAL_RLG',
#   'U-VAL_WRG',
#   'B-VAL_SGP',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'U-FLD_SGD',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'O',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'U-VAL_GDR',
#   'O',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'B-VAL_KRJ',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'B-VAL_SGP',
#   'U-VAL_GDR',
#   'U-VAL_GDR',
#   'B-VAL_KRJ',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'B-FLD_ADR',
#   'L-VAL_ADR',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'O',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'O',
#   'U-VAL_GDR',
#   'L-FLD_GLD',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'I-VAL_SGD',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_KWN',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB',
#   'B-FLD_TTL',
#   'L-VAL_KAB'],
#  ['L-FLD_GLD',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-VAL_ADR',
#   'U-VAL_GDR',
#   'U-VAL_WRG',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'L-VAL_ADR',
#   'U-VAL_WRG',
#   'U-VAL_WRG',
#   'U-VAL_GDR',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'U-VAL_WRG',
#   'U-VAL_WRG',
#   'U-VAL_GDR',
#   'U-VAL_GDR',
#   'U-VAL_WRG',
#   'L-VAL_ADR',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-VAL_ADR',
#   'U-VAL_GDR',
#   'L-VAL_ADR',
#   'L-FLD_KAB',
#   'U-VAL_WRG',
#   'U-VAL_GDR',
#   'I-VAL_RLG',
#   'U-VAL_WRG',
#   'U-VAL_WRG',
#   'L-VAL_ADR',
#   'L-VAL_ADR',
#   'L-VAL_ADR',
#   'U-VAL_WRG',
#   'L-VAL_ADR',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_WRG',
#   'L-FLD_KAB',
#   'U-VAL_WRG',
#   'U-VAL_WRG',
#   'L-FLD_KAB',
#   'B-VAL_TTL',
#   'U-VAL_KCM',
#   'L-FLD_KAB',
#   'U-VAL_WRG',
#   'L-FLD_KAB',
#   'U-VAL_WRG',
#   'U-VAL_WRG',
#   'U-VAL_GDR',
#   'U-VAL_WRG',
#   'L-VAL_ADR',
#   'I-FLD_WRG',
#   'I-VAL_SGD',
#   'U-VAL_WRG',
#   'L-FLD_KAB',
#   'O',
#   'B-VAL_KRJ',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'U-VAL_GDR',
#   'U-VAL_WRG',
#   'B-VAL_TTL',
#   'L-FLD_KAB',
#   'I-VAL_KAB',
#   'B-VAL_TTL',
#   'U-VAL_WRG',
#   'U-VAL_WRG',
#   'L-FLD_KAB',
#   'B-FLD_KWN',
#   'U-VAL_GDR',
#   'U-VAL_WRG',
#   'L-VAL_ADR',
#   'U-VAL_WRG',
#   'L-FLD_KAB',
#   'U-VAL_GDR',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'U-VAL_WRG',
#   'U-VAL_WRG',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'O',
#   'U-VAL_GDR',
#   'L-FLD_KAB',
#   'L-FLD_KAB',
#   'L-VAL_ADR',
#   'U-VAL_WRG',
#   'I-FLD_WRG',
#   'U-VAL_GDR',
#   'L-VAL_ADR',
#   'U-VAL_WRG',
#   'L-VAL_ADR',
#   'U-VAL_WRG',
#   'B-VAL_KRJ',
#   'L-FLD_GLD',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-FLD_GLD',
#   'L-FLD_GLD',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-FLD_GLD',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-FLD_KWN',
#   'B-FLD_KWN',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'B-VAL_NAMA',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'B-VAL_NAMA',
#   'I-FLD_GDR',
#   'I-FLD_GDR',
#   'B-VAL_NAMA',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'I-FLD_GDR',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB',
#   'L-VAL_KAB']]

# %%
task = TaskLayoutLM(model, tokenizer)

# %%
# ckpt_path = '../checkpoints/layoutlm-v2-epoch=6.ckpt'
# task = TaskLayoutLM.load_from_checkpoint(ckpt_path, model=model, tokenizer=tokenizer)
# model = task.model
# model = model.to(device)

# %%
# DEFAULTS used by the Trainer
checkpoint_callback = pl.callbacks.ModelCheckpoint(
    filepath=SAVED_CHECKPOINT_PATH,
#     save_top_k=1,
    verbose=True,
#     monitor='val_loss',
#     mode='min',
    prefix='layoutlm-v2'
)

tb_logger = pl_loggers.TensorBoardLogger(SAVED_LOGS_PATH)
pl.trainer.seed_everything(MANUAL_SEED)
# Out:
# Global seed set to 1261
# 1261

# %%
trainer = pl.Trainer(
    weights_summary=SUMMARY,
    max_epochs=MAX_EPOCH,
    max_steps=MAX_STEPS,
    val_check_interval=1000,
    gpus=1,
    distributed_backend=DISTRIBUTED_BACKEND,
    log_every_n_steps=LOG_FREQ,
    deterministic=DETERMINISTIC,
    benchmark=BENCHMARK,
    logger=tb_logger, 
    checkpoint_callback=checkpoint_callback, 
#     resume_from_checkpoint=CHECKPOINT_PATH
)

trainer.fit(task, train_loader, valid_loader)
# Out:
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-1b3acd732fd6> in <module>
#      14 )
#      15
# ---> 16 trainer.fit(task, train_loader, valid_loader)
#
# /opt/anaconda3/envs/dlearn/lib/python3.6/site-packages/pytorch_lightning/trainer/trainer.py in fit(self, model, train_dataloader, val_dataloaders, datamodule)
#     491         # ----------------------------
#     492         self.accelerator_backend = self.accelerator_connector.select_accelerator()
# --> 493         self.accelerator_backend.setup(model)
#     494
#     495         # ----------------------------
#
# /opt/anaconda3/envs/dlearn/lib/python3.6/site-packages/pytorch_lightning/accelerators/gpu_accelerator.py in setup(self, model)
#      50         # CHOOSE OPTIMIZER
#      51         # allow for lr schedulers as well
# ---> 52         self.setup_optimizers(model)
#      53
#      54         # 16-bit
#
# /opt/anaconda3/envs/dlearn/lib/python3.6/site-packages/pytorch_lightning/accelerators/accelerator.py in setup_optimizers(self, model)
#     148             return
#     149
# --> 150         optimizers, lr_schedulers, optimizer_frequencies = self.trainer.init_optimizers(model)
#     151         self.trainer.optimizers = optimizers
#     152         self.trainer.lr_schedulers = lr_schedulers
#
# /opt/anaconda3/envs/dlearn/lib/python3.6/site-packages/pytorch_lightning/trainer/optimizers.py in init_optimizers(self, model)
#      29 class TrainerOptimizersMixin(ABC):
#      30     def init_optimizers(self, model: LightningModule) -> Tuple[List, List, List]:
# ---> 31         optim_conf = model.configure_optimizers()
#      32         if optim_conf is None:
#      33             rank_zero_warn(
#
# ~/study/code/repo/layoutlm.pytorch/notebook/laylm/trainer/task.py in configure_optimizers(self)
#      89                 "params": [
#      90                     p
# ---> 91                     for n, p in self.model.named_parameters()
#      92                     if not any(nd in n for nd in no_decay)
#      93                 ],
#
# AttributeError: '_IncompatibleKeys' object has no attribute 'named_parameters'

# %%
# ckpt_path = '../checkpoints/layoutlm-layoutlm.ckpt-v1.ckpt'
# loaded_ckpt = torch.load(ckpt_path)

# %%
ckpt_path = '../checkpoints/layoutlm-v2-epoch=6.ckpt'
task = TaskLayoutLM.load_from_checkpoint(ckpt_path, model=model, tokenizer=tokenizer)
model = task.model
model = model.to(device)

# %%
batch = next(iter(valid_loader))
# batch[0]

# valid_loader.dataset[0]

# %%
inputs = {
    "input_ids": batch[0].to(device),
    "attention_mask": batch[1].to(device),
#     "token_type_ids": batch[2].to(device),
    "labels": batch[3].to(device),
    "bbox": batch[4].to(device)
}
outputs = model(**inputs)

# %%
from laylm.trainer import metrics
words, label_preds, label_gts = metrics.normalized_words_labels_preds(inputs, outputs, tokenizer)

accuracy_score(label_preds, label_gts)
f1_score(label_preds, label_gts)
precision_score(label_preds, label_gts)
recall_score(label_preds, label_gts)
# classification_report(label_preds, label_gts)

pd.set_option('display.max_columns', None)
pd.set_option('max_columns', None)
pd.set_option("max_rows", None)
pd.DataFrame({
    'words': words[0],
    'pred': label_preds[0],
    'gt': label_gts[0]
})

# %%
input_data = {
    'input_ids':[],
    'attention_mask': [],
    'bbox': []
}

# %%
model = task.model
torch.save(model.state_dict(), '../weights/layoutlm_v2_ktp_20kv1_vacc_0.981_vloss_0.26.pth')

# %%
state_dict = torch.load('../weights/layoutlm_v2_ktp_20kv1_vacc_0.981_vloss_0.26.pth')
model = model.load_state_dict(state_dict)
# task.model = model
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-3c6a3152fa79> in <module>
#       1 state_dict = torch.load('../weights/layoutlm_v2_ktp_20kv1_vacc_0.981_vloss_0.26.pth')
#       2 model = model.load_state_dict(state_dict)
# ----> 3 task.model = model
#
# /opt/anaconda3/envs/dlearn/lib/python3.6/site-packages/torch/nn/modules/module.py in __setattr__(self, name, value)
#     813                     raise TypeError("cannot assign '{}' as child module '{}' "
#     814                                     "(torch.nn.Module or None expected)"
# --> 815                                     .format(torch.typename(value), name))
#     816                 modules[name] = value
#     817             else:
#
# TypeError: cannot assign 'torch.nn.modules.module._IncompatibleKeys' as child module 'model' (torch.nn.Module or None expected)

# %%
from laylm.data.dataset import IDCardAnnoDataset
from laylm.data import utils
from laylm.config import token as token_cfg
from sklearn.utils import shuffle


path = '/data/idcard/combined/1606753021/'
annoset = IDCardAnnoDataset(path, tokenizer)

# %%
objects = annoset[2005]
objects = shuffle(objects)

data_dict = utils.annoset_transform(objects, tokenizer, max_seq_length=512)
inputs_data = utils.annoset_inputs(data_dict, device=device)

outputs = model(**inputs_data)

label_preds = normalized_prediction(outputs, tokenizer)
data_dict['labels'] = label_preds[0]
data = clean_prediction_data(data_dict, tokenizer)
data = rebuild_prediction_data(data)
data

# %%
annoset[0]

# %%
from laylm.trainer import metrics

def normalized_prediction(outputs, tokenizer):
    preds = prediction_index(outputs)
    
    bsize = preds.shape[0]
    
    labels = []
    for idx in range(bsize):
        label_pred = []
        for pds in preds[idx].tolist():
            lbl = label_cfg.idx_to_label.get(pds, "O")
            label_pred.append(lbl)
        labels.append(label_pred)
    
    return labels

    
def prediction_index(outputs):
    if len(outputs)>1:
        preds = outputs[1]
    else:
        preds = outputs[0]
    preds = torch.argmax(preds, dim=2)
    return preds

def clean_prediction_data(data_dict, tokenizer):
    words = data_dict['words']
    boxes = data_dict['bboxes']
    tokens = data_dict['tokens']
    labels = data_dict['labels']
    gseq = data_dict['gseq']
    wseq = data_dict['wseq']

    data = {
        'words':[],
        'bboxes': [],
        'tokens': [],
        'labels': [],
        'gseq': [],
        'wseq': [],
    }

    for (w,b,t,l,gq,wq) in zip(words, boxes, tokens, labels, gseq, wseq):
        if not (w==tokenizer.cls_token or 
                w==tokenizer.sep_token or 
                w==tokenizer.pad_token):

            data['words'].append(w)
            data['bboxes'].append(b)
            data['tokens'].append(t)
            data['labels'].append(l)
            data['gseq'].append(gq)
            data['wseq'].append(wq)
            
    return data

def sort_multidim(data):
    sorter = lambda x: (x[2][1], x[1])
    # x[2][1] sort by y position
    # x[1] sort by BILOU
    
    return sorted(data, key=sorter)


def word_taken(data):
    str_out = ""
    for idx in range(len(data)):
        w = data[idx][0]
        if w!="" and len(w)!=0:
            str_out += w
            if idx!=len(data)-1:
                str_out += " "
            
    return str_out

from laylm.config import label as label_cfg

def rebuild_prediction_data(data):
    df = pd.DataFrame(data)
    dfg = df.groupby('gseq').aggregate({
        'words': 'min', 
        'bboxes':'last',
        'tokens':'sum',
        'labels':'first'
    })
    
    base_data = dict((k,[]) for k,v in label_cfg.base_label_name.items())
    for idx in range(len(dfg)):
        labels = dfg.iloc[idx]['labels']
        bbox = dfg.iloc[idx]['bboxes']
        if not labels=="O":
            bil, val = labels.split("-")
            val_type, val_label = val.split("_")
            if val_type=="VAL":
                word = dfg.iloc[idx]['words']
                key = label_cfg.label_to_name[val_label]
                base_data[key].append((word, bil, bbox))


    for k,v in base_data.items():
        sorted_data = sort_multidim(v)
        base_data[k] = word_taken(sorted_data)
    
    return base_data

# %%
# dfg
# dfg['bboxes']

# %%
    

base_data

# %%
alamat = base_data['alamat']

# %%
pd.set_option('display.max_columns', None)
pd.set_option('max_columns', None)
pd.set_option("max_rows", None)
pd.DataFrame(data_dict)

# %%
# accuracy_score(label_preds, label_gts)
# f1_score(label_preds, label_gts)
# precision_score(label_preds, label_gts)
# recall_score(label_preds, label_gts)
# classification_report(label_preds, label_gts)

pd.set_option('display.max_columns', None)
pd.set_option('max_columns', None)
pd.set_option("max_rows", None)
pd.DataFrame({
    'word': data_dict['words'],
    'token': words[0],
    'pred': label_preds[0],
})

# %%
words

# %%
# !pip install seqeval
