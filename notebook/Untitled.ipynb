# %%
import cv2 as cv

# %%
# !ls -al /data/idcard/combined/1606753021
# Out:
# total 37780356
# drwxrwxr-x 2 tigapilar tigapilar 9736192 Des  1 04:52 .
# drwxrwxr-x 8 tigapilar tigapilar    4096 Des  1 00:17 ..
# -rw-rw-r-- 1 tigapilar tigapilar  378221 Des  1 02:39 100007_image.jpg
# -rw-rw-r-- 1 tigapilar tigapilar   39016 Des  1 02:39 100007_json.json
# -rw-rw-r-- 1 tigapilar tigapilar   40746 Des  1 02:39 100007_mask.jpg
# -rw-rw-r-- 1 tigapilar tigapilar  299271 Des  1 01:53 100018_image.jpg
# -rw-rw-r-- 1 tigapilar tigapilar   39634 Des  1 01:53 100018_json.json
# -rw-rw-r-- 1 tigapilar tigapilar   22481 Des  1 01:53 100018_mask.jpg
# -rw-rw-r-- 1 tigapilar tigapilar  272693 Des  1 01:35 100022_image.jpg
# -rw-rw-r-- 1 tigapilar tigapilar   37195 Des  1 01:35 100022_json.json
# -rw-rw-r-- 1 tigapilar tigapilar   35091 Des  1 01:35 100022_mask.jpg
# -rw-rw-r-- 1 tigapilar tigapilar  254994 Des  1 00:43 100034_image.jpg
# -rw-rw-r-- 1 tigapilar tigapilar   36664 Des  1 00:43 100034_json.json
# ...
